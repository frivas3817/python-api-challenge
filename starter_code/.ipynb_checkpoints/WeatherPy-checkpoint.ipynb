# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url= "http://api.openweathermap.org/data/2.5/weather?=units=Imperial&APPID=" + weather_api_key
city_data= []
record_count=1
set_count=1

print("Beginning Data Retrieval")
print("------------------------------")

for i, city in enumerate(cities):
    if(i%50==0 and i>=50):
        set_count +=1
        record_count=0
    print("Processing Record %s of Set %s | %s" % (record_count,set_count,city))
    record_count+=1
    city_url= url+"&q=" + city
    try:
        city_weather= requests.get(city_url).json()
        city_data.append({
            "City":city,
            "Lat":city_weather["coord"]["lat"],
            "Lon":city_weather["coord"]["lon"],
            "Max Temp":city_weather["main"]["temp_max"],
            "Humidity":city_weather["main"]["humidity"],
            "Cloudiness":city_weather["clouds"]["all"],
            "Wind Speed":city_weather["wind"]["speed"],
            "Country":city_weather["sys"]["country"],
            "Date":city_weather["dt"]
        })
    except:
        print("City not found.  Skipping...")
        pass
print("---------------------------------")
print("Data Retrieval Complete")
print("---------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | kaeo
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | wanning
# Processing Record 5 of Set 1 | magistralnyy
# Processing Record 6 of Set 1 | kota kinabalu
# Processing Record 7 of Set 1 | achisay
# City not found.  Skipping...
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | nizhneyansk
# City not found.  Skipping...
# Processing Record 12 of Set 1 | tumannyy
# City not found.  Skipping...
# Processing Record 13 of Set 1 | necochea
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | bubaque
# Processing Record 16 of Set 1 | saint-augustin
# Processing Record 17 of Set 1 | mikhaylovka
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | rockport
# Processing Record 22 of Set 1 | tsihombe
# City not found.  Skipping...
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | nouadhibou
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | barentsburg
# City not found.  Skipping...
# Processing Record 31 of Set 1 | karratha
# Processing Record 32 of Set 1 | sorong
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | belyy yar
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 38 of Set 1 | bakchar
# Processing Record 39 of Set 1 | maumere
# Processing Record 40 of Set 1 | saleaula
# City not found.  Skipping...
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | caravelas
# Processing Record 45 of Set 1 | abha
# Processing Record 46 of Set 1 | carauari
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | sidi ali
# Processing Record 50 of Set 1 | vila franca do campo
# Processing Record 0 of Set 2 | berezna
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | rio gallegos
# Processing Record 3 of Set 2 | husavik
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | borama
# City not found.  Skipping...
# Processing Record 6 of Set 2 | buriti dos lopes
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | segou
# Processing Record 12 of Set 2 | cayenne
# Processing Record 13 of Set 2 | slonim
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | aban
# Processing Record 16 of Set 2 | omboue
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | hambantota
# Processing Record 20 of Set 2 | gelemso
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | vallenar
# Processing Record 24 of Set 2 | along
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | portland
# Processing Record 29 of Set 2 | pyay
# Processing Record 30 of Set 2 | jovellar
# Processing Record 31 of Set 2 | hyeres
# Processing Record 32 of Set 2 | flinders
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | kantunilkin
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | de-kastri
# Processing Record 37 of Set 2 | dunedin
# Processing Record 38 of Set 2 | port lincoln
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | amga
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | san francisco
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | paracuru
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | bengkulu
# Processing Record 48 of Set 2 | iracoubo
# Processing Record 49 of Set 2 | borazjan
# Processing Record 0 of Set 3 | hofn
# Processing Record 1 of Set 3 | harrison
# Processing Record 2 of Set 3 | benito juarez
# Processing Record 3 of Set 3 | abnub
# Processing Record 4 of Set 3 | sobolevo
# Processing Record 5 of Set 3 | xuddur
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | sao bento do una
# City not found.  Skipping...
# Processing Record 8 of Set 3 | mountain home
# Processing Record 9 of Set 3 | zapadnaya dvina
# Processing Record 10 of Set 3 | san isidro
# Processing Record 11 of Set 3 | birao
# Processing Record 12 of Set 3 | luderitz
# Processing Record 13 of Set 3 | waitati
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | qurayyat
# Processing Record 16 of Set 3 | xai-xai
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | raudeberg
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | belushya guba
# City not found.  Skipping...
# Processing Record 21 of Set 3 | peniche
# Processing Record 22 of Set 3 | dikson
# Processing Record 23 of Set 3 | bertoua
# Processing Record 24 of Set 3 | freiberg
# Processing Record 25 of Set 3 | gunjur
# Processing Record 26 of Set 3 | gari
# Processing Record 27 of Set 3 | attawapiskat
# City not found.  Skipping...
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | podgornoye
# Processing Record 30 of Set 3 | kopervik
# Processing Record 31 of Set 3 | morgan city
# Processing Record 32 of Set 3 | eltham
# Processing Record 33 of Set 3 | hurghada
# Processing Record 34 of Set 3 | antofagasta
# Processing Record 35 of Set 3 | samusu
# City not found.  Skipping...
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | mayo
# Processing Record 38 of Set 3 | chara
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | lompoc
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | shimsk
# Processing Record 45 of Set 3 | namibe
# Processing Record 46 of Set 3 | marystown
# Processing Record 47 of Set 3 | gornopravdinsk
# Processing Record 48 of Set 3 | mitha tiwana
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 0 of Set 4 | adrar
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | saint-joseph
# Processing Record 3 of Set 4 | payo
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | wajir
# Processing Record 6 of Set 4 | poum
# Processing Record 7 of Set 4 | cap-chat
# Processing Record 8 of Set 4 | arraial do cabo
# Processing Record 9 of Set 4 | weligama
# Processing Record 10 of Set 4 | grindavik
# Processing Record 11 of Set 4 | baykit
# Processing Record 12 of Set 4 | lesozavodsk
# Processing Record 13 of Set 4 | timbakion
# City not found.  Skipping...
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | beringovskiy
# Processing Record 16 of Set 4 | vostok
# Processing Record 17 of Set 4 | cap-aux-meules
# Processing Record 18 of Set 4 | farah
# Processing Record 19 of Set 4 | emporia
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | taolanaro
# City not found.  Skipping...
# Processing Record 23 of Set 4 | mzimba
# Processing Record 24 of Set 4 | xinqing
# Processing Record 25 of Set 4 | saint george
# Processing Record 26 of Set 4 | moyale
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | nalut
# Processing Record 29 of Set 4 | nanortalik
# Processing Record 30 of Set 4 | helong
# Processing Record 31 of Set 4 | gizo
# Processing Record 32 of Set 4 | sao felix do xingu
# Processing Record 33 of Set 4 | paamiut
# Processing Record 34 of Set 4 | katha
# City not found.  Skipping...
# Processing Record 35 of Set 4 | sola
# Processing Record 36 of Set 4 | tema
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | barranca
# Processing Record 39 of Set 4 | amderma
# City not found.  Skipping...
# Processing Record 40 of Set 4 | petatlan
# Processing Record 41 of Set 4 | mitsamiouli
# Processing Record 42 of Set 4 | ondorhaan
# City not found.  Skipping...
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | udachnyy
# Processing Record 45 of Set 4 | mar del plata
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | ngukurr
# City not found.  Skipping...
# Processing Record 48 of Set 4 | killybegs
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 0 of Set 5 | marcona
# City not found.  Skipping...
# Processing Record 1 of Set 5 | hobart
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | vao
# Processing Record 4 of Set 5 | marsh harbour
# Processing Record 5 of Set 5 | sumbe
# Processing Record 6 of Set 5 | the valley
# Processing Record 7 of Set 5 | enugu
# Processing Record 8 of Set 5 | la asuncion
# Processing Record 9 of Set 5 | boyolangu
# Processing Record 10 of Set 5 | hammerfest
# Processing Record 11 of Set 5 | chuy
# Processing Record 12 of Set 5 | pevek
# Processing Record 13 of Set 5 | les cayes
# Processing Record 14 of Set 5 | upernavik
# Processing Record 15 of Set 5 | stornoway
# Processing Record 16 of Set 5 | qaanaaq
# Processing Record 17 of Set 5 | castro
# Processing Record 18 of Set 5 | san rafael
# Processing Record 19 of Set 5 | mahadday weyne
# City not found.  Skipping...
# Processing Record 20 of Set 5 | opuwo
# Processing Record 21 of Set 5 | bauchi
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | roald
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | lusambo
# Processing Record 26 of Set 5 | las varas
# Processing Record 27 of Set 5 | toba tek singh
# Processing Record 28 of Set 5 | kloulklubed
# Processing Record 29 of Set 5 | touros
# Processing Record 30 of Set 5 | nara
# Processing Record 31 of Set 5 | kiama
# Processing Record 32 of Set 5 | poya
# Processing Record 33 of Set 5 | san cristobal
# Processing Record 34 of Set 5 | olafsvik
# Processing Record 35 of Set 5 | ville-marie
# Processing Record 36 of Set 5 | santiago del estero
# Processing Record 37 of Set 5 | aklavik
# Processing Record 38 of Set 5 | tiksi
# Processing Record 39 of Set 5 | port augusta
# Processing Record 40 of Set 5 | rapar
# Processing Record 41 of Set 5 | puerto leguizamo
# Processing Record 42 of Set 5 | sharjah
# Processing Record 43 of Set 5 | high level
# Processing Record 44 of Set 5 | revelstoke
# Processing Record 45 of Set 5 | faanui
# Processing Record 46 of Set 5 | puerto baquerizo moreno
# Processing Record 47 of Set 5 | mys shmidta
# City not found.  Skipping...
# Processing Record 48 of Set 5 | ust-kuyga
# Processing Record 49 of Set 5 | nome
# Processing Record 0 of Set 6 | pathein
# Processing Record 1 of Set 6 | maceio
# Processing Record 2 of Set 6 | leczyca
# Processing Record 3 of Set 6 | black river
# Processing Record 4 of Set 6 | nisia floresta
# Processing Record 5 of Set 6 | alihe
# Processing Record 6 of Set 6 | hithadhoo
# Processing Record 7 of Set 6 | harper
# Processing Record 8 of Set 6 | pavlovsk
# Processing Record 9 of Set 6 | kapuskasing
# Processing Record 10 of Set 6 | barcelos
# Processing Record 11 of Set 6 | saskylakh
# Processing Record 12 of Set 6 | lucapa
# Processing Record 13 of Set 6 | gharb
# City not found.  Skipping...
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | gamba
# Processing Record 16 of Set 6 | lumphat
# Processing Record 17 of Set 6 | quatre cocos
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | barcelona
# Processing Record 20 of Set 6 | hendijan
# City not found.  Skipping...
# Processing Record 21 of Set 6 | gushikawa
# Processing Record 22 of Set 6 | norman wells
# Processing Record 23 of Set 6 | klaksvik
# Processing Record 24 of Set 6 | okhotsk
# Processing Record 25 of Set 6 | nipawin
# Processing Record 26 of Set 6 | leshukonskoye
# Processing Record 27 of Set 6 | tabiauea
# City not found.  Skipping...
# Processing Record 28 of Set 6 | manzhouli
# Processing Record 29 of Set 6 | zhigansk
# Processing Record 30 of Set 6 | louisbourg
# City not found.  Skipping...
# Processing Record 31 of Set 6 | avera
# Processing Record 32 of Set 6 | krasnoselkup
# Processing Record 33 of Set 6 | hovd
# Processing Record 34 of Set 6 | slave lake
# Processing Record 35 of Set 6 | wick
# Processing Record 36 of Set 6 | cotonou
# Processing Record 37 of Set 6 | airai
# Processing Record 38 of Set 6 | la ronge
# Processing Record 39 of Set 6 | dovers
# Processing Record 40 of Set 6 | kuala terengganu
# Processing Record 41 of Set 6 | lyubinskiy
# Processing Record 42 of Set 6 | viedma
# Processing Record 43 of Set 6 | burica
# City not found.  Skipping...
# Processing Record 44 of Set 6 | katobu
# Processing Record 45 of Set 6 | reconquista
# Processing Record 46 of Set 6 | balkanabat
# Processing Record 47 of Set 6 | kidal
# Processing Record 48 of Set 6 | bay roberts
# Processing Record 49 of Set 6 | kyshtovka
# Processing Record 0 of Set 7 | sainte-suzanne
# Processing Record 1 of Set 7 | odweyne
# Processing Record 2 of Set 7 | rawson
# Processing Record 3 of Set 7 | tual
# Processing Record 4 of Set 7 | bhiwani
# Processing Record 5 of Set 7 | san juan
# Processing Record 6 of Set 7 | matay
# Processing Record 7 of Set 7 | rogun
# City not found.  Skipping...
# Processing Record 8 of Set 7 | guerrero negro
# Processing Record 9 of Set 7 | sambava
# Processing Record 10 of Set 7 | frenstat
# Processing Record 11 of Set 7 | graham
# Processing Record 12 of Set 7 | alta floresta
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | pacifica
# Processing Record 15 of Set 7 | macaboboni
# City not found.  Skipping...
# Processing Record 16 of Set 7 | pouebo
# Processing Record 17 of Set 7 | umzimvubu
# City not found.  Skipping...
# Processing Record 18 of Set 7 | ostrovnoy
# Processing Record 19 of Set 7 | coos bay
# Processing Record 20 of Set 7 | sovetskiy
# Processing Record 21 of Set 7 | port hardy
# Processing Record 22 of Set 7 | salisbury
# Processing Record 23 of Set 7 | havre-saint-pierre
# Processing Record 24 of Set 7 | garowe
# Processing Record 25 of Set 7 | kolda
# Processing Record 26 of Set 7 | tomatlan
# Processing Record 27 of Set 7 | comodoro rivadavia
# Processing Record 28 of Set 7 | lagunas
# Processing Record 29 of Set 7 | moorhead
# Processing Record 30 of Set 7 | te anau
# Processing Record 31 of Set 7 | bilma
# Processing Record 32 of Set 7 | khaga
# Processing Record 33 of Set 7 | veraval
# Processing Record 34 of Set 7 | andros town
# Processing Record 35 of Set 7 | luau
# Processing Record 36 of Set 7 | tuatapere
# Processing Record 37 of Set 7 | nakama
# Processing Record 38 of Set 7 | bucak
# Processing Record 39 of Set 7 | kaliyaganj
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | payakumbuh
# Processing Record 42 of Set 7 | fort wellington
# Processing Record 43 of Set 7 | pedernales
# Processing Record 44 of Set 7 | hamilton
# Processing Record 45 of Set 7 | beidao
# Processing Record 46 of Set 7 | khovu-aksy
# Processing Record 47 of Set 7 | ixtapa
# Processing Record 48 of Set 7 | fukagawa
# Processing Record 49 of Set 7 | arlit
# Processing Record 0 of Set 8 | kruisfontein
# Processing Record 1 of Set 8 | bukama
# Processing Record 2 of Set 8 | anadyr
# Processing Record 3 of Set 8 | jumla
# Processing Record 4 of Set 8 | bentiu
# Processing Record 5 of Set 8 | santa rosalia
# Processing Record 6 of Set 8 | norfolk
# Processing Record 7 of Set 8 | sedelnikovo
# City not found.  Skipping...
# Processing Record 8 of Set 8 | puerto escondido
# Processing Record 9 of Set 8 | sumenep
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | constitucion
# Processing Record 12 of Set 8 | santa marta
# Processing Record 13 of Set 8 | clyde river
# Processing Record 14 of Set 8 | cidreira
# Processing Record 15 of Set 8 | mount isa
# Processing Record 16 of Set 8 | geraldton
# Processing Record 17 of Set 8 | ozernovskiy
# Processing Record 18 of Set 8 | siofok
# Processing Record 19 of Set 8 | shimoda
# Processing Record 20 of Set 8 | bur gabo
# City not found.  Skipping...
# Processing Record 21 of Set 8 | lourinha
# Processing Record 22 of Set 8 | sorvag
# City not found.  Skipping...
# Processing Record 23 of Set 8 | ligayan
# Processing Record 24 of Set 8 | umm kaddadah
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | okakarara
# Processing Record 28 of Set 8 | szentgotthard
# Processing Record 29 of Set 8 | pimentel
# Processing Record 30 of Set 8 | khonuu
# City not found.  Skipping...
# Processing Record 31 of Set 8 | magalia
# Processing Record 32 of Set 8 | rosario
# City not found.  Skipping...
# Processing Record 33 of Set 8 | muros
# Processing Record 34 of Set 8 | sioux lookout
# Processing Record 35 of Set 8 | walvis bay
# Processing Record 36 of Set 8 | dingle
# Processing Record 37 of Set 8 | san quintin
# Processing Record 38 of Set 8 | tautira
# Processing Record 39 of Set 8 | visnes
# Processing Record 40 of Set 8 | chicama
# Processing Record 41 of Set 8 | andenes
# Processing Record 42 of Set 8 | methoni
# Processing Record 43 of Set 8 | nevelsk
# Processing Record 44 of Set 8 | sainte-thecle
# Processing Record 45 of Set 8 | ruatoria
# City not found.  Skipping...
# Processing Record 46 of Set 8 | beyneu
# Processing Record 47 of Set 8 | campbellsville
# Processing Record 48 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 8 | codrington
# Processing Record 0 of Set 9 | laguna
# Processing Record 1 of Set 9 | kununurra
# Processing Record 2 of Set 9 | fukue
# Processing Record 3 of Set 9 | nenjiang
# Processing Record 4 of Set 9 | toliary
# City not found.  Skipping...
# Processing Record 5 of Set 9 | bossembele
# City not found.  Skipping...
# Processing Record 6 of Set 9 | monte cristi
# City not found.  Skipping...
# Processing Record 7 of Set 9 | hoa binh
# Processing Record 8 of Set 9 | east london
# Processing Record 9 of Set 9 | chihuahua
# Processing Record 10 of Set 9 | santa rosa
# Processing Record 11 of Set 9 | thinadhoo
# Processing Record 12 of Set 9 | riachao das neves
# Processing Record 13 of Set 9 | fidenza
# Processing Record 14 of Set 9 | beloha
# Processing Record 15 of Set 9 | paita
# Processing Record 16 of Set 9 | dolbeau
# City not found.  Skipping...
# Processing Record 17 of Set 9 | egvekinot
# Processing Record 18 of Set 9 | agadez
# Processing Record 19 of Set 9 | waingapu
# Processing Record 20 of Set 9 | batagay
# Processing Record 21 of Set 9 | huoqiu
# Processing Record 22 of Set 9 | grand river south east
# City not found.  Skipping...
# Processing Record 23 of Set 9 | esna
# Processing Record 24 of Set 9 | sibolga
# Processing Record 25 of Set 9 | kichmengskiy gorodok
# Processing Record 26 of Set 9 | puerto del rosario
# Processing Record 27 of Set 9 | talnakh
# Processing Record 28 of Set 9 | rio grande
# Processing Record 29 of Set 9 | sorsk
# Processing Record 30 of Set 9 | bargal
# City not found.  Skipping...
# Processing Record 31 of Set 9 | malibu
# Processing Record 32 of Set 9 | jalu
# Processing Record 33 of Set 9 | turayf
# Processing Record 34 of Set 9 | harwich
# Processing Record 35 of Set 9 | komsomolskiy
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | lolua
# City not found.  Skipping...
# Processing Record 38 of Set 9 | juybar
# Processing Record 39 of Set 9 | pochutla
# Processing Record 40 of Set 9 | zyryanka
# Processing Record 41 of Set 9 | tecoanapa
# Processing Record 42 of Set 9 | eureka
# Processing Record 43 of Set 9 | aswan
# Processing Record 44 of Set 9 | temaraia
# City not found.  Skipping...
# Processing Record 45 of Set 9 | casian
# Processing Record 46 of Set 9 | maloy
# Processing Record 47 of Set 9 | troitsko-pechorsk
# Processing Record 48 of Set 9 | asosa
# Processing Record 49 of Set 9 | asau
# Processing Record 0 of Set 10 | kindu
# Processing Record 1 of Set 10 | jacksonville
# Processing Record 2 of Set 10 | taiyuan
# Processing Record 3 of Set 10 | saryagash
# Processing Record 4 of Set 10 | nagato
# Processing Record 5 of Set 10 | khani
# Processing Record 6 of Set 10 | lata
# Processing Record 7 of Set 10 | scarborough
# Processing Record 8 of Set 10 | alekseyevka
# Processing Record 9 of Set 10 | tunduru
# City not found.  Skipping...
# Processing Record 10 of Set 10 | chernyshevskiy
# Processing Record 11 of Set 10 | melfi
# Processing Record 12 of Set 10 | zunyi
# Processing Record 13 of Set 10 | edson
# Processing Record 14 of Set 10 | dawson creek
# Processing Record 15 of Set 10 | qujing
# Processing Record 16 of Set 10 | broken hill
# Processing Record 17 of Set 10 | wukari
# Processing Record 18 of Set 10 | acapulco
# Processing Record 19 of Set 10 | svetlaya
# Processing Record 20 of Set 10 | meadow lake
# Processing Record 21 of Set 10 | cabedelo
# Processing Record 22 of Set 10 | alliston
# Processing Record 23 of Set 10 | pedreiras
# Processing Record 24 of Set 10 | paradwip
# City not found.  Skipping...
# Processing Record 25 of Set 10 | lev tolstoy
# Processing Record 26 of Set 10 | erdenet
# Processing Record 27 of Set 10 | rabat
# Processing Record 28 of Set 10 | springfield
# Processing Record 29 of Set 10 | sajanan
# Processing Record 30 of Set 10 | hirara
# Processing Record 31 of Set 10 | terrace
# Processing Record 32 of Set 10 | ambagarh chauki
# Processing Record 33 of Set 10 | aneho
# Processing Record 34 of Set 10 | halalo
# City not found.  Skipping...
# Processing Record 35 of Set 10 | yerbogachen
# Processing Record 36 of Set 10 | kunming
# Processing Record 37 of Set 10 | saint-paul
# Processing Record 38 of Set 10 | coahuayana
# Processing Record 39 of Set 10 | baraboo
# Processing Record 40 of Set 10 | manado
# Processing Record 41 of Set 10 | yian
# City not found.  Skipping...
# Processing Record 42 of Set 10 | pampas
# Processing Record 43 of Set 10 | kudahuvadhoo
# Processing Record 44 of Set 10 | vila velha
# Processing Record 45 of Set 10 | sao raimundo das mangabeiras
# Processing Record 46 of Set 10 | lashio
# Processing Record 47 of Set 10 | shumskiy
# Processing Record 48 of Set 10 | dambulla
# Processing Record 49 of Set 10 | nakamura
# Processing Record 0 of Set 11 | warqla
# City not found.  Skipping...
# Processing Record 1 of Set 11 | gorontalo
# Processing Record 2 of Set 11 | san miguel
# Processing Record 3 of Set 11 | atikokan
# Processing Record 4 of Set 11 | aykhal
# Processing Record 5 of Set 11 | margate
# Processing Record 6 of Set 11 | requena
# Processing Record 7 of Set 11 | kalianget
# Processing Record 8 of Set 11 | salta
# Processing Record 9 of Set 11 | almaznyy
# Processing Record 10 of Set 11 | piran
# Processing Record 11 of Set 11 | kangalassy
# Processing Record 12 of Set 11 | brownsville
# Processing Record 13 of Set 11 | monrovia
# Processing Record 14 of Set 11 | fairbanks
# Processing Record 15 of Set 11 | fallon
# Processing Record 16 of Set 11 | gat
# Processing Record 17 of Set 11 | gazimurskiy zavod
# Processing Record 18 of Set 11 | tracy
# Processing Record 19 of Set 11 | shcholkine
# City not found.  Skipping...
# Processing Record 20 of Set 11 | ust-omchug
# Processing Record 21 of Set 11 | kysyl-syr
# Processing Record 22 of Set 11 | alice springs
# Processing Record 23 of Set 11 | laukaa
# Processing Record 24 of Set 11 | cheuskiny
# City not found.  Skipping...
# Processing Record 25 of Set 11 | marawi
# Processing Record 26 of Set 11 | montlucon
# Processing Record 27 of Set 11 | qaracala
# Processing Record 28 of Set 11 | kousseri
# Processing Record 29 of Set 11 | loknya
# Processing Record 30 of Set 11 | nijar
# Processing Record 31 of Set 11 | ust-ilimsk
# Processing Record 32 of Set 11 | atherton
# Processing Record 33 of Set 11 | emerald
# Processing Record 34 of Set 11 | limbang
# Processing Record 35 of Set 11 | alofi
# Processing Record 36 of Set 11 | kenai
# Processing Record 37 of Set 11 | banjar
# Processing Record 38 of Set 11 | ketchikan
# Processing Record 39 of Set 11 | baghdad
# Processing Record 40 of Set 11 | baiyin
# Processing Record 41 of Set 11 | cheyenne
# Processing Record 42 of Set 11 | point fortin
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | lianzhou
# Processing Record 45 of Set 11 | northam
# Processing Record 46 of Set 11 | chilca
# Processing Record 47 of Set 11 | camalu
# Processing Record 48 of Set 11 | hagenow
# Processing Record 49 of Set 11 | karur
# Processing Record 0 of Set 12 | ucluelet
# Processing Record 1 of Set 12 | mizpe ramon
# City not found.  Skipping...
# Processing Record 2 of Set 12 | karaul
# City not found.  Skipping...
# Processing Record 3 of Set 12 | murray bridge
# Processing Record 4 of Set 12 | broome
# Processing Record 5 of Set 12 | pacific grove
# Processing Record 6 of Set 12 | ous
# Processing Record 7 of Set 12 | dunayivtsi
# City not found.  Skipping...
# Processing Record 8 of Set 12 | tete
# Processing Record 9 of Set 12 | forio
# Processing Record 10 of Set 12 | aktash
# Processing Record 11 of Set 12 | santa luzia
# Processing Record 12 of Set 12 | tigil
# Processing Record 13 of Set 12 | yate
# Processing Record 14 of Set 12 | bathsheba
# Processing Record 15 of Set 12 | tessalit
# Processing Record 16 of Set 12 | raska
# Processing Record 17 of Set 12 | mnogovershinnyy
# Processing Record 18 of Set 12 | dabou
# Processing Record 19 of Set 12 | sao filipe
# Processing Record 20 of Set 12 | carlagan
# Processing Record 21 of Set 12 | gombong
# Processing Record 22 of Set 12 | ponta delgada
# Processing Record 23 of Set 12 | farafangana
# Processing Record 24 of Set 12 | irimbo
# Processing Record 25 of Set 12 | whitefish
# Processing Record 26 of Set 12 | sorland
# Processing Record 27 of Set 12 | bolungarvik
# City not found.  Skipping...
# Processing Record 28 of Set 12 | iskateley
# Processing Record 29 of Set 12 | bulgan
# Processing Record 30 of Set 12 | pangody
# Processing Record 31 of Set 12 | wakkanai
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | newport
# Processing Record 34 of Set 12 | koulikoro
# Processing Record 35 of Set 12 | rawah
# Processing Record 36 of Set 12 | kedougou
# Processing Record 37 of Set 12 | ambilobe
# Processing Record 38 of Set 12 | uyovu
# Processing Record 39 of Set 12 | chimbote
# Processing Record 40 of Set 12 | saint-martin-boulogne
# Processing Record 41 of Set 12 | stara synyava
# Processing Record 42 of Set 12 | pemba
# Processing Record 43 of Set 12 | san carlos de bariloche
# Processing Record 44 of Set 12 | lensk
# Processing Record 45 of Set 12 | itacoatiara
# Processing Record 46 of Set 12 | khandagayty
# ---------------------------------
# Data Retrieval Complete
# ---------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": cities})

weather_data = {
     "City": cities,
     "Cloudiness": cloudiness,
     "Country": country,
     "Date": date,
     "Humidity": humidity,
     "Lat": lat,
     "Lng": lng,
     "Max Temp": max_temp,
     "Wind Speed": wind_speed    
 }

# Create the data frame and count variables for each columns
weather_df = pd.DataFrame(weather_data)
weather_df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d63bb44ed1cc> in <module>
#       3 weather_data = {
#       4      "City": cities,
# ----> 5      "Cloudiness": cloudiness,
#       6      "Country": country,
#       7      "Date": date,
#
# NameError: name 'cloudiness' is not defined

# %%
weather_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Max Temperature (F)"], color='blue', alpha=0.5)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.datetime.now().strftime("%D")})')
plt.savefig("./output_data/LatVsMaxTemp.png")
plt.show()
print("The plot proves that as we generally move away from the equator, temperature drops")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Humidity (%)"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.datetime.now().strftime("%D")})')
plt.savefig("./output_data/LatVsHumidity.png")
plt.show()
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Cloudiness (%)"], color='blue', alpha=0.5)
plt.grid()
plt.ylim(-20,(df_countries["Cloudiness (%)"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.datetime.now().strftime("%D")})')
plt.savefig("./output_data/LatVsCloudiness.png")
plt.show()
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_countries["Latitude"], df_countries["Wind Speed (mph)"], color='blue', alpha=0.5)
plt.grid()
plt.ylim((df_countries["Wind Speed (mph)"].min()-5),(df_countries["Wind Speed (mph)"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.datetime.now().strftime("%D")})')
plt.savefig("./output_data/LatVsWind.png")
plt.show()
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bb0904313945> in <module>
# ----> 1 x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
#       2 y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
#       3 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'northern_df' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-874b6b53e693> in <module>
# ----> 1 x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
#       2 y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
#       3 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'southern_df' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c538dcb743c4> in <module>
# ----> 1 x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
#       2 y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
#       3 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'northern_df' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ee83716a3696> in <module>
# ----> 1 x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
#       2 y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
#       3 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'southern_df' is not defined

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-bd8fcb6c1ac2> in <module>
# ----> 1 x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
#       2 y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
#       3 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       4 regress_values = x_values * slope + intercept
#       5 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'northern_df' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# The r-squared is: -0.322483077139538
